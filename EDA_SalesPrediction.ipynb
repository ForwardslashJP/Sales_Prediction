# %% [markdown]
# # EDA Predicción de Ventas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amankharwal/Website-data/master/advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# El dataset utilizado para este analisis, muestra el gasto en publicidad en tres diferentes casos (TV,Radio,Periodicos), para finalmente obtener el numero de ventas que se obtuvieron segun lo que se invirtió en publicidad.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# Inicialmente los tipos de datos de cada columna, corresponde a los datos que contiene cada una. Además cuenta con 200 datos para cada columna, y ningun dato faltante.

# %% [markdown]
# ### TV

# %%
sns.histplot(x='TV', data= df, kde=True)
plt.show()
plt.boxplot(df['TV'])
plt.show()
print(df.TV.describe())
# Out:
# count    200.000000
# mean     147.042500
# std       85.854236
# min        0.700000
# 25%       74.375000
# 50%      149.750000
# 75%      218.825000
# max      296.400000
# Name: TV, dtype: float64

# %% [markdown]
# La distribucion de los valores de publicidad en Television no muestra un comportamiento evidente. Estos datos van desde los 0.7 dolares a 296.4 dolares.

# %% [markdown]
# Por otro lado, no cuenta con datos atipicos extremos. Podria decirse que el rango de valores es usualmente utilizados por los diferentes usuarios para promocionar sus productos. Incluso podemos ver la mayor cantidad de personas invierte entre 200 dolares y 235 dolares, seguido la segunda mayor cantidad de personas que invierten entre 0.7-34 dolares; y 67-100 dolares con 27 personas cada rango.

# %% [markdown]
# ### Radio

# %%
sns.histplot(x='Radio', data= df, kde=True)
plt.show()
plt.boxplot(df['Radio'])
plt.show()
print(df.Radio.describe())
# Out:
# count    200.000000
# mean      23.264000
# std       14.846809
# min        0.000000
# 25%        9.975000
# 50%       22.900000
# 75%       36.525000
# max       49.600000
# Name: Radio, dtype: float64

# %% [markdown]
# Para la parte de Radio, vemos que tampoco hay un comportamiento evidente en la distribucion de los datos. Si podemos decir que no hay valores extremos en sus datos.

# %% [markdown]
# Podemos evidenciar que comparado con la TV, el costo que invierten las personas es mucho menor, mientras que para TV el rango va de 0.7-300 dolares, aqui se invierte desde 0-50 dolares. Una diferencia bastante notable.

# %% [markdown]
# El histograma muestra que la mayor cantidad de personas invierte entre 0-6 dolares de publicidad en la radio, con mas de 30 personas en el conteo de estos datos. El resto de valores de inversion oscila entre 15-25 personas.

# %% [markdown]
# ### Newspaper

# %%
sns.histplot(x='Newspaper', data= df, kde=True)
plt.show()
plt.boxplot(df['Newspaper'])
plt.show()
print(df.Newspaper.describe())
# Out:
# count    200.000000
# mean      30.554000
# std       21.778621
# min        0.300000
# 25%       12.750000
# 50%       25.750000
# 75%       45.100000
# max      114.000000
# Name: Newspaper, dtype: float64

# %% [markdown]
# Para la columna de Periodico, vemos una distribucion sesgada positiva. Evidencia quue las personas que invierte en publicidad en este medio, es menor a medida que aumenta el valor.

# %% [markdown]
# La mayor cantidad de personas que invierten en dinero lo hace entre 0-11 dolares, y decreciendo hasta el maximo valor entre 103-114 dolares.

# %% [markdown]
# Vemos que hay dos valores atipicos, que son valores extremos que ha invertido las personas en publicidad de peridico, excediento los 100 dolares.

# %% [markdown]
# Comparando el rango de valores entre la Radio y el Periodico, el 75% de personas invierten 45 dolares en periodico que es casi la cantidad total que invierten las personas en la Radio.

# %% [markdown]
# ### Sales

# %%
sns.histplot(x='Sales', data= df, kde=True)
plt.show()
plt.boxplot(df['Sales'])
plt.show()
print(df.Sales.describe())
# Out:
# count    200.000000
# mean      15.130500
# std        5.283892
# min        1.600000
# 25%       11.000000
# 50%       16.000000
# 75%       19.050000
# max       27.000000
# Name: Sales, dtype: float64

# %% [markdown]
# ### Relacion entre variables

# %%
sns.heatmap(df.corr('spearman'),annot=True)
plt.show()

# %% [markdown]
# La imagen muestra que todos los medios de publicidad tienen una relacion positiva con respecto a las ventas. Pero la tv tiene una relacion fuerte, indicando que la mayoria de veces entre mas se invierta en este medio , mayor es la cantidad de ventas, siendo este el de mayor influencia en las ventas, a diferencia de los medios de radio y periodico donde la relacion es debil.

# %% [markdown]
# Tambien, entre los mismos medios tienen una relacion positiva, pero entre cada uno esta relacion es debil. Esto no implica o no da la posibilidad de que al invertir mucho en un medio se invierta de igual forma en otro.

# %% [markdown]
# ### Sales vs TV

# %%
sns.lmplot(x='TV', y='Sales', data=df)
plt.show()

# %% [markdown]
# Era evidente el resultado de esta grafica. Es bastante notoria la relacion, a medida que aumenta la inversion de publicidad en TV, es posible que aumente las ventas.

# %% [markdown]
# ### Sales vs Radio

# %%
sns.lmplot(x='Radio', y='Sales', data=df)
plt.show()

# %% [markdown]
# Como mostraba la relacion de spearman entre la radio y las ventas, la relacion no es evidente, aunque es positiva, es muy debil, los datos se encuentran bastante dispersos. Es un medio que no tienen mucha influencia sobre las ventas, incluso independientemente de cuanta cantidad de dinero se invierta en publicidad es incierto que genere mas o menos ventas.

# %% [markdown]
# ### Sales vs Newspaper

# %%
sns.lmplot(x='Newspaper', y='Sales', data=df)
plt.show()

# %% [markdown]
# Incluso como la Radio la relacion con las ventas, esta no es evidente, aunque es positiva, es muy debil, los datos se encuentran bastante dispersos. Es un medio que no tienen mucha influencia sobre las ventas, incluso independientemente de cuanta cantidad de dinero se invierta en publicidad es incierto que genere mas o menos ventas. Algo que si se puede observar es que los valores extremos (los mayores de 100 dolares de inversion en newspaper) hacen que es que el sombreado de la linea indica expansion, pero es algo que esta afectando a la relacion. Por esa razon eliminaremos ese dato.

# %%
df = df[~(df['Newspaper'] >=100)]

# %% [markdown]
# ### Conclusión

# %% [markdown]
# Finalmente, los datos nos informan que invertir en la TV te da una posibilidad mayor de realizar mas ventas, mientras que con la radio y newspaper es incierto poder dar esa información.

# %% [markdown]
# Ahora el objetivo es poder crear un modelo para predecir las ventas segun la cantidad de dinero que se invierten en los medios de comunicación.
